# %%
import pandas as pd
import numpy as np
import os

# %%
# Read the Excel file
excel_file = pd.read_excel('data/BZE_LW Deutsche Version/LABORDATEN.xlsx')

# Save it as a CSV file
excel_file.to_csv('LABORDATEN.csv', index=False)

# %%
df = pd.read_csv('LABORDATEN.csv')

# %%
df.head()
# Out:
#    PointID  Bundesland  Tiefenstufe Obergrenze  Tiefenstufe Untergrenze  \
# 0        2  SH                               0                       10
# 1        2  SH                              10                       30
# 2        2  SH                              30                       50
# 3        2  SH                              50                       70
# 4        2  SH                              70                      100
#
#    Horizont Untergrenze   gS    mS    fS    gU   mU  ...  Wassergehalt  \
# 0                  28.0  5.8  33.4  35.4  13.1  3.2  ...         20.21
# 1                  28.0  6.7  32.0  35.8  13.3  3.2  ...         19.58
# 2                  54.0  5.0  27.9  37.8  17.5  3.5  ...         15.74
# 3                  68.0  7.6  31.4  36.6  14.4  3.0  ...         11.75
# 4                  96.0  5.8  43.1  42.3   4.1  1.3  ...          5.93
#
#    Steindichte  TRD_Ges  Skelett_Vol-% Mn_Ox  Fe_Ox  Al_Ox  Mn_Di  Fe_Di  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17189 entries, 0 to 17188
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PointID                  17189 non-null  int64
#  1   Bundesland               17189 non-null  object
#  2   Tiefenstufe Obergrenze   17189 non-null  int64
#  3   Tiefenstufe Untergrenze  17189 non-null  int64
#  4   Horizont Untergrenze     17186 non-null  float64
#  5   gS                       16708 non-null  float64
#  6   mS                       16708 non-null  float64
#  7   fS                       16708 non-null  float64
#  8   gU                       16708 non-null  float64
#  9   mU                       16708 non-null  float64
#  10  fU                       16708 non-null  float64
#  11  Sand                     16708 non-null  float64
#  12  Schluff                  16708 non-null  float64
#  13  Ton                      16708 non-null  float64
# ...

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# PointID                        0
# Bundesland                     0
# Tiefenstufe Obergrenze         0
# Tiefenstufe Untergrenze        0
# Horizont Untergrenze           3
# gS                           481
# mS                           481
# fS                           481
# gU                           481
# mU                           481
# fU                           481
# Sand                         481
# Schluff                      481
# Ton                          481
# Bodenart                       0
# pH_H2O                         0
# EC_H2O                         0
# pH_CaCl2                       0
# TC                             0
# TOC                            0
# TIC                            0
# TN                             4
# TS                         14717
# TRD_FB                         6
# FBV                            6
# Wassergehalt                  55
# Steindichte                  319
# TRD_Ges                     3789
# ...

# %%
columns_with_nans = nan_counts[nan_counts > 0]
print(columns_with_nans)
# Out:
# Horizont Untergrenze        3
# gS                        481
# mS                        481
# fS                        481
# gU                        481
# mU                        481
# fU                        481
# Sand                      481
# Schluff                   481
# Ton                       481
# TN                          4
# TS                      14717
# TRD_FB                      6
# FBV                         6
# Wassergehalt               55
# Steindichte               319
# TRD_Ges                  3789
# Skelett_Vol-%              18
# Mn_Ox                   15452
# Fe_Ox                   15452
# Al_Ox                   15452
# Mn_Di                   15870
# Fe_Di                   15870
# Al_Di                   15870
# dtype: int64

# %%
# Read the Excel files
horizontdaten = pd.read_excel('data/BZE_LW Deutsche Version/HORIZONTDATEN.xlsx')
standort = pd.read_excel('data/BZE_LW Deutsche Version/STANDORT.xlsx')

# Save them as CSV files
horizontdaten.to_csv('HORIZONTDATEN.csv', index=False)
standort.to_csv('STANDORT.csv', index=False)
